# %%
from plot import one_org_vs_many
from geogiant.common.settings import PathSettings, ClickhouseSettings

path_settings = PathSettings()
clickhouse_settings = ClickhouseSettings()

# %% [markdown]
# # 2 best org

# %%
one_org_vs_many(
    eval_dir=path_settings.RESULTS_PATH / "tier2_evaluation",
    output_path=path_settings.FIGURE_PATH / "one_org_vs_many.png",
    metric_evaluated="d_error",
)
# Out:
# 2024-05-02 19:26:16.424 | INFO     | plot:one_org_vs_many:695 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier2_evaluation/results__10_hostname_3_orgs.pickle') loaded
# 2024-05-02 19:26:16.430 | INFO     | plot:plot_ecs_shortest_ping:314 - ECS SP:: jaccard, <40km=0.66, 10 hostnames
# 2024-05-02 19:26:16.431 | INFO     | plot:plot_ecs_shortest_ping:317 - ECS SP:: jaccard, median_error=10.96 [km], 10 hostnames
# 2024-05-02 19:26:16.761 | INFO     | plot:one_org_vs_many:695 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier2_evaluation/results__100_hostname_3_orgs.pickle') loaded
# 2024-05-02 19:26:16.765 | INFO     | plot:plot_ecs_shortest_ping:314 - ECS SP:: jaccard, <40km=0.67, 100 hostnames
# 2024-05-02 19:26:16.767 | INFO     | plot:plot_ecs_shortest_ping:317 - ECS SP:: jaccard, median_error=10.17 [km], 100 hostnames
# 2024-05-02 19:26:17.028 | INFO     | plot:one_org_vs_many:695 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier2_evaluation/results__10_hostname_7_orgs.pickle') loaded
# 2024-05-02 19:26:17.032 | INFO     | plot:plot_ecs_shortest_ping:314 - ECS SP:: jaccard, <40km=0.75, 10 hostnames
# 2024-05-02 19:26:17.034 | INFO     | plot:plot_ecs_shortest_ping:317 - ECS SP:: jaccard, median_error=7.89 [km], 10 hostnames
# 2024-05-02 19:26:17.365 | INFO     | plot:one_org_vs_many:695 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier2_evaluation/results__100_hostname_7_orgs.pickle') loaded
# 2024-05-02 19:26:17.370 | INFO     | plot:plot_ecs_shortest_ping:314 - ECS SP:: jaccard, <40km=0.75, 100 hostnames
# 2024-05-02 19:26:17.371 | INFO     | plot:plot_ecs_shortest_ping:317 - ECS SP:: jaccard, median_error=7.81 [km], 100 hostnames
