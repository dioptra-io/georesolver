# %%
from plot import one_org_vs_many
from geogiant.common.settings import PathSettings, ClickhouseSettings

path_settings = PathSettings()
clickhouse_settings = ClickhouseSettings()

# %% [markdown]
# # 2 best org

# %%
one_org_vs_many(
    eval_dir=path_settings.RESULTS_PATH / "tier2_evaluation",
    output_path=path_settings.FIGURE_PATH / "one_org_vs_many.png",
    metric_evaluated="d_error",
    legend_pos="lower right",
)
# Out:
# 2024-05-07 07:50:15.262 | INFO     | plot:one_org_vs_many:749 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier2_evaluation/results__3_hostname_1_orgs.pickle') loaded
# 2024-05-07 07:50:15.267 | INFO     | plot:plot_ecs_shortest_ping:445 - ECS SP:: jaccard, <40km=0.61, 3 hostnames
# 2024-05-07 07:50:15.269 | INFO     | plot:plot_ecs_shortest_ping:448 - ECS SP:: jaccard, median_error=13.95 [km], 3 hostnames
# 2024-05-07 07:50:15.499 | INFO     | plot:one_org_vs_many:749 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier2_evaluation/results__5_hostname_1_orgs.pickle') loaded
# 2024-05-07 07:50:15.503 | INFO     | plot:plot_ecs_shortest_ping:445 - ECS SP:: jaccard, <40km=0.63, 5 hostnames
# 2024-05-07 07:50:15.504 | INFO     | plot:plot_ecs_shortest_ping:448 - ECS SP:: jaccard, median_error=11.62 [km], 5 hostnames
# 2024-05-07 07:50:15.767 | INFO     | plot:one_org_vs_many:749 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier2_evaluation/results__10_hostname_1_orgs.pickle') loaded
# 2024-05-07 07:50:15.771 | INFO     | plot:plot_ecs_shortest_ping:445 - ECS SP:: jaccard, <40km=0.62, 10 hostnames
# 2024-05-07 07:50:15.772 | INFO     | plot:plot_ecs_shortest_ping:448 - ECS SP:: jaccard, median_error=11.76 [km], 10 hostnames
# 2024-05-07 07:50:16.013 | INFO     | plot:one_org_vs_many:749 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier2_evaluation/results__100_hostname_1_orgs.pickle') loaded
# 2024-05-07 07:50:16.018 | INFO     | plot:plot_ecs_shortest_ping:445 - ECS SP:: jaccard, <40km=0.63, 100 hostnames
# 2024-05-07 07:50:16.020 | INFO     | plot:plot_ecs_shortest_ping:448 - ECS SP:: jaccard, median_error=10.97 [km], 100 hostnames
# 2024-05-07 07:50:16.267 | INFO     | plot:one_org_vs_many:749 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier2_evaluation/results__3_hostname_7_orgs.pickle') loaded
# 2024-05-07 07:50:16.271 | INFO     | plot:plot_ecs_shortest_ping:445 - ECS SP:: jaccard, <40km=0.72, 3 hostnames
# 2024-05-07 07:50:16.272 | INFO     | plot:plot_ecs_shortest_ping:448 - ECS SP:: jaccard, median_error=7.98 [km], 3 hostnames
# 2024-05-07 07:50:16.528 | INFO     | plot:one_org_vs_many:749 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier2_evaluation/results__5_hostname_7_orgs.pickle') loaded
# 2024-05-07 07:50:16.533 | INFO     | plot:plot_ecs_shortest_ping:445 - ECS SP:: jaccard, <40km=0.74, 5 hostnames
# 2024-05-07 07:50:16.534 | INFO     | plot:plot_ecs_shortest_ping:448 - ECS SP:: jaccard, median_error=7.3 [km], 5 hostnames
# 2024-05-07 07:50:16.960 | INFO     | plot:one_org_vs_many:749 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier2_evaluation/results__10_hostname_7_orgs.pickle') loaded
# 2024-05-07 07:50:16.964 | INFO     | plot:plot_ecs_shortest_ping:445 - ECS SP:: jaccard, <40km=0.75, 10 hostnames
# 2024-05-07 07:50:16.965 | INFO     | plot:plot_ecs_shortest_ping:448 - ECS SP:: jaccard, median_error=7.49 [km], 10 hostnames
# 2024-05-07 07:50:17.240 | INFO     | plot:one_org_vs_many:749 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier2_evaluation/results__100_hostname_7_orgs.pickle') loaded
# 2024-05-07 07:50:17.244 | INFO     | plot:plot_ecs_shortest_ping:445 - ECS SP:: jaccard, <40km=0.75, 100 hostnames
# 2024-05-07 07:50:17.245 | INFO     | plot:plot_ecs_shortest_ping:448 - ECS SP:: jaccard, median_error=7.75 [km], 100 hostnames
