# %%
from plot import plot_end_to_end_results
from geogiant.common.settings import PathSettings, ClickhouseSettings

path_settings = PathSettings()
clickhouse_settings = ClickhouseSettings()

# %%
plot_end_to_end_results(
    eval_dir=path_settings.RESULTS_PATH / "tier3_evaluation",
    granularities=["answer_subnets"],
    score_metrics=["jaccard"],
    probing_budgets_evaluated=[10, 20, 50],
    imc_nb_vps=[10],
    metric_evaluated="d_error",
)
# Out:
# 2024-04-29 14:45:23.456 | INFO     | plot:plot_end_to_end_results:469 - file='results__best_hostname_geo_score.pickle' loaded
# 2024-04-29 14:45:23.457 | INFO     | plot:plot_end_to_end_results:478 - Answer subnets granularity::
# 2024-04-29 14:45:23.458 | INFO     | plot:plot_per_granularity:125 - len(total_hostnames)=387
# 2024-04-29 14:45:23.458 | INFO     | plot:plot_per_granularity:126 - nb targets:: 759
# 2024-04-29 14:45:23.467 | INFO     | plot:plot_per_granularity:158 - ECS shortest ping:: jaccard, 10 VPs, median_error=9.31 [km], 387 hostnames
# 2024-04-29 14:45:23.470 | INFO     | plot:plot_per_granularity:158 - ECS shortest ping:: jaccard, 20 VPs, median_error=7.37 [km], 387 hostnames
# 2024-04-29 14:45:23.472 | INFO     | plot:plot_per_granularity:158 - ECS shortest ping:: jaccard, 50 VPs, median_error=6.14 [km], 387 hostnames
# 2024-04-29 14:45:23.482 | INFO     | plot:plot_per_granularity:186 - Zero ping:: jaccard, median_error=37.8 [km]
# 2024-04-29 14:45:23.484 | INFO     | plot:plot_per_granularity:188 - ###############################
# 2024-04-29 14:45:23.487 | INFO     | plot:plot_end_to_end_results:515 - Reference shortest ping:: median_error=5.04 [km]
# 2024-04-29 14:45:23.490 | INFO     | plot:plot_end_to_end_results:540 - IMC baseline SP, 10 init VPs, median_error=5.87 [km]

# %%
plot_end_to_end_results(
    eval_dir=path_settings.RESULTS_PATH / "tier3_evaluation",
    granularities=["answer_subnets"],
    score_metrics=["jaccard"],
    probing_budgets_evaluated=[10, 20, 50],
    imc_nb_vps=[10],
    metric_evaluated="rtt",
    legend_pos="lower right",
)
# Out:
# 2024-04-29 14:45:33.809 | INFO     | plot:plot_end_to_end_results:469 - file='results__best_hostname_geo_score.pickle' loaded
# 2024-04-29 14:45:33.812 | INFO     | plot:plot_end_to_end_results:478 - Answer subnets granularity::
# 2024-04-29 14:45:33.813 | INFO     | plot:plot_per_granularity:125 - len(total_hostnames)=387
# 2024-04-29 14:45:33.815 | INFO     | plot:plot_per_granularity:126 - nb targets:: 759
# 2024-04-29 14:45:33.825 | INFO     | plot:plot_per_granularity:158 - ECS shortest ping:: jaccard, 10 VPs, median_error=1.37 [km], 387 hostnames
# 2024-04-29 14:45:33.829 | INFO     | plot:plot_per_granularity:158 - ECS shortest ping:: jaccard, 20 VPs, median_error=1.05 [km], 387 hostnames
# 2024-04-29 14:45:33.832 | INFO     | plot:plot_per_granularity:158 - ECS shortest ping:: jaccard, 50 VPs, median_error=0.86 [km], 387 hostnames
# 2024-04-29 14:45:33.834 | INFO     | plot:plot_per_granularity:188 - ###############################
# 2024-04-29 14:45:33.839 | INFO     | plot:plot_end_to_end_results:515 - Reference shortest ping:: median_error=0.72 [km]
# 2024-04-29 14:45:33.842 | INFO     | plot:plot_end_to_end_results:540 - IMC baseline SP, 10 init VPs, median_error=0.75 [km]
