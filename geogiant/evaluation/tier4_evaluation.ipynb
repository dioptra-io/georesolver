# %%
from plot import bgp_prefix_threshold
from table import bgp_prefix_threshold_data
from geogiant.common.settings import PathSettings, ClickhouseSettings

path_settings = PathSettings()
clickhouse_settings = ClickhouseSettings()

# %% [markdown]
# # Tier 4 Geoloc error

# %%
bgp_prefix_threshold(
    eval_dir=path_settings.RESULTS_PATH / "tier4_evaluation",
    output_path="bgp_prefix_threshold",
    metric_evaluated="d_error",
    plot_zp=False,
)
# Out:
# 2024-05-07 07:49:54.613 | INFO     | plot:bgp_prefix_threshold:828 - bgp_prefix_threshold=20
# 2024-05-07 07:49:54.975 | INFO     | plot:bgp_prefix_threshold:832 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier4_evaluation/results__best_hostname_geo_score_20_BGP_3_hostnames_per_org_ns.pickle') loaded
# 2024-05-07 07:49:54.979 | INFO     | plot:plot_ecs_shortest_ping:445 - ECS SP:: jaccard, <40km=0.78, 389 hostnames
# 2024-05-07 07:49:54.980 | INFO     | plot:plot_ecs_shortest_ping:448 - ECS SP:: jaccard, median_error=6.25 [km], 389 hostnames
# 2024-05-07 07:49:54.981 | INFO     | plot:bgp_prefix_threshold:828 - bgp_prefix_threshold=100
# 2024-05-07 07:49:55.240 | INFO     | plot:bgp_prefix_threshold:832 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier4_evaluation/results__best_hostname_geo_score_100_BGP_3_hostnames_per_org_ns.pickle') loaded
# 2024-05-07 07:49:55.245 | INFO     | plot:plot_ecs_shortest_ping:445 - ECS SP:: jaccard, <40km=0.76, 129 hostnames
# 2024-05-07 07:49:55.246 | INFO     | plot:plot_ecs_shortest_ping:448 - ECS SP:: jaccard, median_error=6.79 [km], 129 hostnames

# %% [markdown]
# # Tier3 VP selection

# %%
data = bgp_prefix_threshold_data(
    eval_dir=path_settings.RESULTS_PATH / "tier4_evaluation",
    metric_evaluated="d_error",
)
# Out:
# 2024-05-07 07:49:56.661 | INFO     | table:bgp_prefix_threshold_data:239 - bgp_prefix_threshold=5
# 2024-05-07 07:49:56.940 | INFO     | table:bgp_prefix_threshold_data:243 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier4_evaluation/results__best_hostname_geo_score_5_BGP_3_hostnames_per_org_ns.pickle') loaded
# 2024-05-07 07:49:56.943 | INFO     | table:get_data_from_results:190 - ECS SP:: jaccard, <40km=0.78, 808 hostnames
# 2024-05-07 07:49:56.945 | INFO     | table:get_data_from_results:193 - ECS SP:: jaccard, median_error=6.2 [km], 808 hostnames
# 2024-05-07 07:49:56.947 | INFO     | table:zero_ping_data:120 - Zero ping:: jaccard, median_error=43.89 [km]
# 2024-05-07 07:49:56.948 | INFO     | table:bgp_prefix_threshold_data:239 - bgp_prefix_threshold=5
# 2024-05-07 07:49:57.286 | INFO     | table:bgp_prefix_threshold_data:243 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier4_evaluation/results__best_hostname_geo_score_5_BGP_5_hostnames_per_org_ns.pickle') loaded
# 2024-05-07 07:49:57.290 | INFO     | table:get_data_from_results:190 - ECS SP:: jaccard, <40km=0.78, 1070 hostnames
# 2024-05-07 07:49:57.291 | INFO     | table:get_data_from_results:193 - ECS SP:: jaccard, median_error=6.18 [km], 1070 hostnames
# 2024-05-07 07:49:57.295 | INFO     | table:zero_ping_data:120 - Zero ping:: jaccard, median_error=42.29 [km]
# 2024-05-07 07:49:57.296 | INFO     | table:bgp_prefix_threshold_data:239 - bgp_prefix_threshold=5
# 2024-05-07 07:49:57.560 | INFO     | table:bgp_prefix_threshold_data:243 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier4_evaluation/results__best_hostname_geo_score_5_BGP_10_hostnames_per_org_ns.pickle') loaded
# 2024-05-07 07:49:57.564 | INFO     | table:get_data_from_results:190 - ECS SP:: jaccard, <40km=0.78, 1503 hostnames
# 2024-05-07 07:49:57.566 | INFO     | table:get_data_from_results:193 - ECS SP:: jaccard, median_error=6.13 [km], 1503 hostnames
# 2024-05-07 07:49:57.569 | INFO     | table:zero_ping_data:120 - Zero ping:: jaccard, median_error=32.39 [km]
# 2024-05-07 07:49:57.571 | INFO     | table:bgp_prefix_threshold_data:239 - bgp_prefix_threshold=10
# 2024-05-07 07:49:58.042 | INFO     | table:bgp_prefix_threshold_data:243 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier4_evaluation/results__best_hostname_geo_score_10_BGP_3_hostnames_per_org_ns.pickle') loaded
# 2024-05-07 07:49:58.047 | INFO     | table:get_data_from_results:190 - ECS SP:: jaccard, <40km=0.78, 556 hostnames
# 2024-05-07 07:49:58.049 | INFO     | table:get_data_from_results:193 - ECS SP:: jaccard, median_error=6.25 [km], 556 hostnames
# 2024-05-07 07:49:58.053 | INFO     | table:zero_ping_data:120 - Zero ping:: jaccard, median_error=34.14 [km]
# 2024-05-07 07:49:58.055 | INFO     | table:bgp_prefix_threshold_data:239 - bgp_prefix_threshold=10
# 2024-05-07 07:49:58.320 | INFO     | table:bgp_prefix_threshold_data:243 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier4_evaluation/results__best_hostname_geo_score_10_BGP_5_hostnames_per_org_ns.pickle') loaded
# 2024-05-07 07:49:58.324 | INFO     | table:get_data_from_results:190 - ECS SP:: jaccard, <40km=0.79, 753 hostnames
# 2024-05-07 07:49:58.326 | INFO     | table:get_data_from_results:193 - ECS SP:: jaccard, median_error=6.22 [km], 753 hostnames
# 2024-05-07 07:49:58.329 | INFO     | table:zero_ping_data:120 - Zero ping:: jaccard, median_error=37.78 [km]
# 2024-05-07 07:49:58.330 | INFO     | table:bgp_prefix_threshold_data:239 - bgp_prefix_threshold=10
# 2024-05-07 07:49:58.615 | INFO     | table:bgp_prefix_threshold_data:243 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier4_evaluation/results__best_hostname_geo_score_10_BGP_10_hostnames_per_org_ns.pickle') loaded
# 2024-05-07 07:49:58.619 | INFO     | table:get_data_from_results:190 - ECS SP:: jaccard, <40km=0.78, 1098 hostnames
# 2024-05-07 07:49:58.621 | INFO     | table:get_data_from_results:193 - ECS SP:: jaccard, median_error=6.14 [km], 1098 hostnames
# 2024-05-07 07:49:58.625 | INFO     | table:zero_ping_data:120 - Zero ping:: jaccard, median_error=32.39 [km]
# 2024-05-07 07:49:58.626 | INFO     | table:bgp_prefix_threshold_data:239 - bgp_prefix_threshold=20
# 2024-05-07 07:49:59.003 | INFO     | table:bgp_prefix_threshold_data:243 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier4_evaluation/results__best_hostname_geo_score_20_BGP_3_hostnames_per_org_ns.pickle') loaded
# 2024-05-07 07:49:59.009 | INFO     | table:get_data_from_results:190 - ECS SP:: jaccard, <40km=0.78, 389 hostnames
# 2024-05-07 07:49:59.010 | INFO     | table:get_data_from_results:193 - ECS SP:: jaccard, median_error=6.25 [km], 389 hostnames
# 2024-05-07 07:49:59.014 | INFO     | table:zero_ping_data:120 - Zero ping:: jaccard, median_error=32.85 [km]
# 2024-05-07 07:49:59.015 | INFO     | table:bgp_prefix_threshold_data:239 - bgp_prefix_threshold=20
# 2024-05-07 07:49:59.389 | INFO     | table:bgp_prefix_threshold_data:243 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier4_evaluation/results__best_hostname_geo_score_20_BGP_5_hostnames_per_org_ns.pickle') loaded
# 2024-05-07 07:49:59.393 | INFO     | table:get_data_from_results:190 - ECS SP:: jaccard, <40km=0.78, 527 hostnames
# 2024-05-07 07:49:59.394 | INFO     | table:get_data_from_results:193 - ECS SP:: jaccard, median_error=6.14 [km], 527 hostnames
# 2024-05-07 07:49:59.398 | INFO     | table:zero_ping_data:120 - Zero ping:: jaccard, median_error=41.17 [km]
# 2024-05-07 07:49:59.399 | INFO     | table:bgp_prefix_threshold_data:239 - bgp_prefix_threshold=20
# 2024-05-07 07:49:59.747 | INFO     | table:bgp_prefix_threshold_data:243 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier4_evaluation/results__best_hostname_geo_score_20_BGP_10_hostnames_per_org_ns.pickle') loaded
# 2024-05-07 07:49:59.751 | INFO     | table:get_data_from_results:190 - ECS SP:: jaccard, <40km=0.79, 785 hostnames
# 2024-05-07 07:49:59.752 | INFO     | table:get_data_from_results:193 - ECS SP:: jaccard, median_error=6.14 [km], 785 hostnames
# 2024-05-07 07:49:59.755 | INFO     | table:zero_ping_data:120 - Zero ping:: jaccard, median_error=40.4 [km]
# 2024-05-07 07:49:59.757 | INFO     | table:bgp_prefix_threshold_data:239 - bgp_prefix_threshold=50
# 2024-05-07 07:50:00.239 | INFO     | table:bgp_prefix_threshold_data:243 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier4_evaluation/results__best_hostname_geo_score_50_BGP_3_hostnames_per_org_ns.pickle') loaded
# 2024-05-07 07:50:00.243 | INFO     | table:get_data_from_results:190 - ECS SP:: jaccard, <40km=0.78, 224 hostnames
# 2024-05-07 07:50:00.245 | INFO     | table:get_data_from_results:193 - ECS SP:: jaccard, median_error=6.36 [km], 224 hostnames
# 2024-05-07 07:50:00.248 | INFO     | table:zero_ping_data:120 - Zero ping:: jaccard, median_error=48.87 [km]
# 2024-05-07 07:50:00.249 | INFO     | table:bgp_prefix_threshold_data:239 - bgp_prefix_threshold=50
# 2024-05-07 07:50:00.523 | INFO     | table:bgp_prefix_threshold_data:243 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier4_evaluation/results__best_hostname_geo_score_50_BGP_5_hostnames_per_org_ns.pickle') loaded
# 2024-05-07 07:50:00.527 | INFO     | table:get_data_from_results:190 - ECS SP:: jaccard, <40km=0.77, 315 hostnames
# 2024-05-07 07:50:00.529 | INFO     | table:get_data_from_results:193 - ECS SP:: jaccard, median_error=6.45 [km], 315 hostnames
# 2024-05-07 07:50:00.532 | INFO     | table:zero_ping_data:120 - Zero ping:: jaccard, median_error=45.34 [km]
# 2024-05-07 07:50:00.534 | INFO     | table:bgp_prefix_threshold_data:239 - bgp_prefix_threshold=50
# 2024-05-07 07:50:00.845 | INFO     | table:bgp_prefix_threshold_data:243 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier4_evaluation/results__best_hostname_geo_score_50_BGP_10_hostnames_per_org_ns.pickle') loaded
# 2024-05-07 07:50:00.849 | INFO     | table:get_data_from_results:190 - ECS SP:: jaccard, <40km=0.77, 493 hostnames
# 2024-05-07 07:50:00.851 | INFO     | table:get_data_from_results:193 - ECS SP:: jaccard, median_error=6.25 [km], 493 hostnames
# 2024-05-07 07:50:00.857 | INFO     | table:zero_ping_data:120 - Zero ping:: jaccard, median_error=42.01 [km]
# 2024-05-07 07:50:00.858 | INFO     | table:bgp_prefix_threshold_data:239 - bgp_prefix_threshold=100
# 2024-05-07 07:50:01.122 | INFO     | table:bgp_prefix_threshold_data:243 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier4_evaluation/results__best_hostname_geo_score_100_BGP_3_hostnames_per_org_ns.pickle') loaded
# 2024-05-07 07:50:01.127 | INFO     | table:get_data_from_results:190 - ECS SP:: jaccard, <40km=0.76, 129 hostnames
# 2024-05-07 07:50:01.128 | INFO     | table:get_data_from_results:193 - ECS SP:: jaccard, median_error=6.79 [km], 129 hostnames
# 2024-05-07 07:50:01.132 | INFO     | table:zero_ping_data:120 - Zero ping:: jaccard, median_error=96.49 [km]
# 2024-05-07 07:50:01.133 | INFO     | table:bgp_prefix_threshold_data:239 - bgp_prefix_threshold=100
# 2024-05-07 07:50:01.423 | INFO     | table:bgp_prefix_threshold_data:243 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier4_evaluation/results__best_hostname_geo_score_100_BGP_5_hostnames_per_org_ns.pickle') loaded
# 2024-05-07 07:50:01.427 | INFO     | table:get_data_from_results:190 - ECS SP:: jaccard, <40km=0.76, 184 hostnames
# 2024-05-07 07:50:01.429 | INFO     | table:get_data_from_results:193 - ECS SP:: jaccard, median_error=6.53 [km], 184 hostnames
# 2024-05-07 07:50:01.432 | INFO     | table:zero_ping_data:120 - Zero ping:: jaccard, median_error=104.25 [km]
# 2024-05-07 07:50:01.433 | INFO     | table:bgp_prefix_threshold_data:239 - bgp_prefix_threshold=100
# 2024-05-07 07:50:01.719 | INFO     | table:bgp_prefix_threshold_data:243 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier4_evaluation/results__best_hostname_geo_score_100_BGP_10_hostnames_per_org_ns.pickle') loaded
# 2024-05-07 07:50:01.722 | INFO     | table:get_data_from_results:190 - ECS SP:: jaccard, <40km=0.76, 285 hostnames
# 2024-05-07 07:50:01.724 | INFO     | table:get_data_from_results:193 - ECS SP:: jaccard, median_error=6.53 [km], 285 hostnames
# 2024-05-07 07:50:01.727 | INFO     | table:zero_ping_data:120 - Zero ping:: jaccard, median_error=90.72 [km]

# %%
for row in data:
    if row[0] == "SP":
        print(row[1:])
# Out:
# (5, 3, 808, 6.2, 0.78)
# (5, 5, 1070, 6.18, 0.78)
# (5, 10, 1503, 6.13, 0.78)
# (10, 3, 556, 6.25, 0.78)
# (10, 5, 753, 6.22, 0.79)
# (10, 10, 1098, 6.14, 0.78)
# (20, 3, 389, 6.25, 0.78)
# (20, 5, 527, 6.14, 0.78)
# (20, 10, 785, 6.14, 0.79)
# (50, 3, 224, 6.36, 0.78)
# (50, 5, 315, 6.45, 0.77)
# (50, 10, 493, 6.25, 0.77)
# (100, 3, 129, 6.79, 0.76)
# (100, 5, 184, 6.53, 0.76)
# (100, 10, 285, 6.53, 0.76)

# %%
for row in data:
    if row[0] == "ZP":
        print(row[1:])
# Out:
# (5, 3, 808, 43.89, 0.49)
# (5, 5, 1070, 42.29, 0.49)
# (5, 10, 1503, 32.39, 0.52)
# (10, 3, 556, 34.14, 0.52)
# (10, 5, 753, 37.78, 0.51)
# (10, 10, 1098, 32.39, 0.52)
# (20, 3, 389, 32.85, 0.52)
# (20, 5, 527, 41.17, 0.5)
# (20, 10, 785, 40.4, 0.5)
# (50, 3, 224, 48.87, 0.48)
# (50, 5, 315, 45.34, 0.48)
# (50, 10, 493, 42.01, 0.5)
# (100, 3, 129, 96.49, 0.4)
# (100, 5, 184, 104.25, 0.38)
# (100, 10, 285, 90.72, 0.4)
