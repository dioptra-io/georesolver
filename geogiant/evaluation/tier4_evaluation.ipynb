# %%
from plot import bgp_prefix_threshold
from geogiant.common.settings import PathSettings, ClickhouseSettings

path_settings = PathSettings()
clickhouse_settings = ClickhouseSettings()

# %% [markdown]
# # Tier 3 Geoloc error

# %%
bgp_prefix_threshold(
    eval_dir=path_settings.RESULTS_PATH / "tier4_evaluation",
    output_path="bgp_prefix_threshold",
    metric_evaluated="d_error",
    plot_zp=False,
)
# Out:
# 2024-05-02 19:27:05.851 | INFO     | plot:bgp_prefix_threshold:729 - bgp_prefix_threshold=5
# 2024-05-02 19:27:06.256 | INFO     | plot:bgp_prefix_threshold:733 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier4_evaluation/results__best_hostname_geo_score_5_BGP.pickle') loaded
# 2024-05-02 19:27:06.262 | INFO     | plot:plot_ecs_shortest_ping:314 - ECS SP:: jaccard, <40km=0.77, 680 hostnames
# 2024-05-02 19:27:06.263 | INFO     | plot:plot_ecs_shortest_ping:317 - ECS SP:: jaccard, median_error=6.14 [km], 680 hostnames
# 2024-05-02 19:27:06.264 | INFO     | plot:bgp_prefix_threshold:729 - bgp_prefix_threshold=10
# 2024-05-02 19:27:06.573 | INFO     | plot:bgp_prefix_threshold:733 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier4_evaluation/results__best_hostname_geo_score_10_BGP.pickle') loaded
# 2024-05-02 19:27:06.578 | INFO     | plot:plot_ecs_shortest_ping:314 - ECS SP:: jaccard, <40km=0.79, 443 hostnames
# 2024-05-02 19:27:06.580 | INFO     | plot:plot_ecs_shortest_ping:317 - ECS SP:: jaccard, median_error=6.07 [km], 443 hostnames
# 2024-05-02 19:27:06.582 | INFO     | plot:bgp_prefix_threshold:729 - bgp_prefix_threshold=20
# 2024-05-02 19:27:06.868 | INFO     | plot:bgp_prefix_threshold:733 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier4_evaluation/results__best_hostname_geo_score_20_BGP.pickle') loaded
# 2024-05-02 19:27:06.872 | INFO     | plot:plot_ecs_shortest_ping:314 - ECS SP:: jaccard, <40km=0.79, 285 hostnames
# 2024-05-02 19:27:06.873 | INFO     | plot:plot_ecs_shortest_ping:317 - ECS SP:: jaccard, median_error=6.07 [km], 285 hostnames
# 2024-05-02 19:27:06.875 | INFO     | plot:bgp_prefix_threshold:729 - bgp_prefix_threshold=50
# 2024-05-02 19:27:07.150 | INFO     | plot:bgp_prefix_threshold:733 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier4_evaluation/results__best_hostname_geo_score_50_BGP.pickle') loaded
# 2024-05-02 19:27:07.160 | INFO     | plot:plot_ecs_shortest_ping:314 - ECS SP:: jaccard, <40km=0.79, 159 hostnames
# 2024-05-02 19:27:07.161 | INFO     | plot:plot_ecs_shortest_ping:317 - ECS SP:: jaccard, median_error=6.19 [km], 159 hostnames
# 2024-05-02 19:27:07.163 | INFO     | plot:bgp_prefix_threshold:729 - bgp_prefix_threshold=100
# 2024-05-02 19:27:07.454 | INFO     | plot:bgp_prefix_threshold:733 - file=PosixPath('/storage/hugo/geogiant/geogiant/common/../results/tier4_evaluation/results__best_hostname_geo_score_100_BGP.pickle') loaded
# 2024-05-02 19:27:07.460 | INFO     | plot:plot_ecs_shortest_ping:314 - ECS SP:: jaccard, <40km=0.77, 92 hostnames
# 2024-05-02 19:27:07.461 | INFO     | plot:plot_ecs_shortest_ping:317 - ECS SP:: jaccard, median_error=6.97 [km], 92 hostnames

# %% [markdown]
# # Tier3 VP selection

# %%
score_metrics_and_granularity(
    eval_dir=path_settings.RESULTS_PATH / "tier3_evaluation",
    output_path="score_metrics_and_granularity",
    metric_evaluated="rtt",
    plot_zp=False,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 score_metrics_and_granularity(
#       2     eval_dir=path_settings.RESULTS_PATH / "tier3_evaluation",
#       3     output_path="score_metrics_and_granularity",
#       4     metric_evaluated="rtt",
#       5     plot_zp=False,
#       6 )
#
# NameError: name 'score_metrics_and_granularity' is not defined
